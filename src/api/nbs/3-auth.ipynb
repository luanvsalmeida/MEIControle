# %% [markdown]
# ## Sign Up

# %%
import requests
path = "/api/auth/signup"
base_url = "http://localhost:8002"
create_endpoint = f"{base_url}{path}"

response = requests.post(create_endpoint, json={"username": "Carla Maria",
                                                "email": "carla_maria@mail.com",
                                                "password": "maria123",
                                                "business": "confeitaria"})
print(response.headers)
print('ok', response.ok)
if response.ok:
    data = response.json()
    print(data, type(data), data.get('items'))
else:
    print(response.text)
# Out:
# {'date': 'Fri, 09 May 2025 15:09:11 GMT', 'server': 'uvicorn', 'content-length': '210', 'content-type': 'application/json'}
# ok True
# {'userId': 1, 'password': '$2b$12$TMqkAhqDSblzsYKvuR7syOg2/go35Yikm98Dt68elw7EQrP6gZXKC', 'created_at': '2025-05-09T15:09:12.964101Z', 'business': 'confeitaria', 'username': 'Carla Maria', 'email': 'carla_maria@mail.com'} <class 'dict'> None

# %% [markdown]
# ## Sign In

# %%
path = "/api/auth/signin"
base_url = "http://localhost:8002"
create_endpoint = f"{base_url}{path}"

response = requests.post(create_endpoint, json={"email": "marla_caria@mail.com",
                                                "password": "malia123"})
print(response.headers)
print('ok', response.ok)
if response.ok:
    data = response.json()
    print(data, type(data), data.get('items'))
else:
    print(response.text)
# Out:
# {'date': 'Fri, 09 May 2025 15:09:29 GMT', 'server': 'uvicorn', 'content-length': '160', 'content-type': 'application/json'}
# ok True
# {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiIxIiwiZXhwIjoxNzQ2ODA0MjY5fQ.2f4QUlewyNdzoYJeaS1bd92v0jV5_7PrC0CPE4wnIos', 'token_type': 'bearer'} <class 'dict'> None

# %% [markdown]
# ## Edit Account

# %%
path = "/api/auth/1"
base_url = "http://localhost:8002"
create_endpoint = f"{base_url}{path}"

response = requests.put(create_endpoint, json={"username": "marla caria",
                                                "email": "marla_caria@mail.com",
                                                "password": "malia123",
                                                "business": "tráfigo de drogas"
                                                })
print(response.headers)
print('ok', response.ok)
if response.ok:
    data = response.json()
    print(data, type(data), data.get('items'))
else:
    print(response.text)
# Out:
# {'date': 'Fri, 09 May 2025 15:09:26 GMT', 'server': 'uvicorn', 'content-length': '217', 'content-type': 'application/json'}
# ok True
# {'userId': 1, 'password': '$2b$12$qKRQt.m9rdCpSVcundsOr.gdOJwO.IBR5fDA3q9y432UEka4WuWby', 'created_at': '2025-05-09T15:09:12.964101Z', 'business': 'tráfigo de drogas', 'username': 'marla caria', 'email': 'marla_caria@mail.com'} <class 'dict'> None
