# %%
import requests
path = "/api/events/"
base_url = "http://localhost:8002"
endpoint = f"{base_url}{path}"

# %%
response = requests.get(endpoint)

# %%
print(response.ok)
# Out:
# True

# %%
if response.ok:
    data = response.json()
    print(data, type(data), data.get('items'))
# Out:
# {'items': [{'id': 1}, {'id': 2}, {'id': 3}], 'count': 3} <class 'dict'> [{'id': 1}, {'id': 2}, {'id': 3}]

# %%
data = {"page": "/test+"}

# %%
import json

json.dumps(data)
# Out:
# '{"items": [{"id": 1}, {"id": 2}, {"id": 3}], "count": 3}'

# %%
path = "/api/events/"
base_url = "http://localhost:8002"
create_endpoint = f"{base_url}{path}"

response = requests.post(create_endpoint, json={"page": "/test+", "description": "abc"})
print(response.text)
print(response.headers)
print('ok', response.ok)
if response.ok: 
    data = response.json()
    print(data, type(data), data.get('items'))
else:
    print(response.text)
# Out:
# {"id":1,"page":"/test+","description":""}
# {'date': 'Tue, 06 May 2025 20:57:59 GMT', 'server': 'uvicorn', 'content-length': '41', 'content-type': 'application/json'}
# ok True
# {'id': 1, 'page': '/test+', 'description': ''} <class 'dict'> None

# %%
detail_path = "/api/events/12/"
detail_endpoint = f"{base_url}{detail_path}"
headers = {
    "Content-Type": "application/json"
}
response = requests.put(detail_endpoint, json={"description": "hello world"}) # HTTP PUT
print(response.text)
print(response.headers)
print('ok', response.ok)
if response.ok: 
    data = response.json()
    print(data, type(data), data.get('items'))
else:
    print(response.text)
# Out:
# {"id":12,"page":"","description":"hello world"}
# {'date': 'Tue, 06 May 2025 20:57:17 GMT', 'server': 'uvicorn', 'content-length': '47', 'content-type': 'application/json'}
# ok True
# {'id': 12, 'page': '', 'description': 'hello world'} <class 'dict'> None
