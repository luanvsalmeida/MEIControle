# %%
import requests
path = "/api/events/"
base_url = "http://localhost:8002"
endpoint = f"{base_url}{path}"

# %%
detail_path = "/api/events/2"
detail_endpoint = f"{base_url}{detail_path}"
headers = {
    "Content-Type": "application/json"
}
response = requests.put(detail_endpoint, json={"description": "hello world"}) # HTTP PUT
print(response.text)
print(response.headers)
print('ok', response.ok)
if response.ok: 
    data = response.json()
    print(data, type(data), data.get('items'))
else:
    print(response.text)
# Out:
# {"page":"/test+","description":"hello world","id":2,"created_at":"2025-05-10T03:40:28.516083Z","updated_at":"2025-05-10T03:40:39.119615Z"}
# {'date': 'Sat, 10 May 2025 03:40:39 GMT', 'server': 'uvicorn', 'content-length': '138', 'content-type': 'application/json'}
# ok True
# {'page': '/test+', 'description': 'hello world', 'id': 2, 'created_at': '2025-05-10T03:40:28.516083Z', 'updated_at': '2025-05-10T03:40:39.119615Z'} <class 'dict'> None

# %%
path = "/api/events"
base_url = "http://localhost:8002"
create_endpoint = f"{base_url}{path}"

response = requests.post(create_endpoint, json={"page": "/test+", "description": "123"})
print(response.headers)
print('ok', response.ok)
if response.ok:
    data = response.json()
    print(data, type(data), data.get('items'))
else:
    print(response.text)
# Out:
# {'date': 'Sat, 10 May 2025 03:40:29 GMT', 'server': 'uvicorn', 'content-length': '131', 'content-type': 'application/json'}
# ok True
# {'page': '/test+', 'description': '123', 'id': 10, 'created_at': '2025-05-10T03:40:30.725905Z', 'updated_at': '2025-05-10T03:40:30.725912Z'} <class 'dict'> None

# %%
path = "/api/events"
base_url = "http://localhost:8002"
create_endpoint = f"{base_url}{path}"
response = requests.get(create_endpoint)
print("ok", response.ok)
if response.ok:
    print(response.json())
# Out:
# ok True
# {'results': [{'id': 4, 'page': '/test+', 'created_at': '2025-05-08T05:57:08.860184Z', 'description': '123'}, {'id': 3, 'page': '/test+', 'created_at': '2025-05-08T05:57:08.679808Z', 'description': '123'}, {'id': 2, 'page': '/test+', 'created_at': '2025-05-08T05:57:08.440110Z', 'description': '123'}, {'id': 1, 'page': '/test+', 'created_at': '2025-05-08T05:57:08.280674Z', 'description': '123'}], 'count': 4}

# %%
response = requests.get(f"{endpoint}14")
print("ok", response.ok)
if response.ok:
    print(response.json())
# Out:
# ok False

# %%
detail_path = "/api/events/10/"
detail_endpoint = f"{base_url}{detail_path}"
headers = {
    "Content-Type": "application/json"
}
response = requests.put(detail_endpoint, json={"description": "it's the number 10"}) # HTTP PUT
print(response.text)
print(response.headers)
print('ok', response.ok)
if response.ok: 
    data = response.json()
    print(data, type(data), data.get('items'))
else:
    print(response.text)
# Out:
# {"id":10,"description":"it's the number 10","page":"/test+"}
# {'date': 'Thu, 08 May 2025 05:45:00 GMT', 'server': 'uvicorn', 'content-length': '60', 'content-type': 'application/json'}
# ok True
# {'id': 10, 'description': "it's the number 10", 'page': '/test+'} <class 'dict'> None
