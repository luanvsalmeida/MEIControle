# %% [markdown]
# ## Inflow

# %%
import requests
path = "/api/inflow"
base_url = "http://localhost:8002"
create_endpoint = f"{base_url}{path}"

response = requests.post(create_endpoint, json={"userId": 1, 
                                                "client": "Carla Severina",
                                                "value": 40,
                                                "type": "produto",
                                                "paymentForm": "dinheiro"
                                                })
print(response.headers)
print('ok', response.ok)
if response.ok:
    data = response.json()
    print(data, type(data), data.get('items'))
else:
    print(response.text)
# Out:
# {'date': 'Tue, 13 May 2025 17:02:00 GMT', 'server': 'uvicorn', 'content-length': '143', 'content-type': 'application/json'}
# ok True
# {'userId': 1, 'inflowId': 3, 'value': 40.0, 'type': 'produto', 'date': '2025-05-13T17:02:01.198949Z', 'client': 'Carla Severina', 'paymentForm': 'dinheiro'} <class 'dict'> None

# %%
path = "/api/inflow/by_user/1"
base_url = "http://localhost:8002"
create_endpoint = f"{base_url}{path}"
response = requests.get(create_endpoint)
print("ok", response.ok)
if response.ok:
    print(response.json())
# Out:
# ok True
# {'results': [{'userId': 1, 'inflowId': 1, 'value': 50.0, 'type': 'produto', 'date': '2025-05-13T16:59:31.685821Z', 'client': 'João', 'paymentForm': 'crédito'}, {'userId': 1, 'inflowId': 3, 'value': 40.0, 'type': 'produto', 'date': '2025-05-13T17:02:01.198949Z', 'client': 'Carla Severina', 'paymentForm': 'dinheiro'}], 'count': 2}

# %%
path = "/api/inflow/1"
base_url = "http://localhost:8002"
create_endpoint = f"{base_url}{path}"
response = requests.get(create_endpoint)
print("ok", response.ok)
if response.ok:
    print(response.json())
# Out:
# ok True
# {'userId': 1, 'inflowId': 1, 'value': 50.0, 'type': 'produto', 'date': '2025-05-13T16:59:31.685821Z', 'client': 'João', 'paymentForm': 'crédito'}

# %% [markdown]
# ## Outflow

# %%
import requests
path = "/api/outflow"
base_url = "http://localhost:8002"
create_endpoint = f"{base_url}{path}"

response = requests.post(create_endpoint, json={"userId": 1, 
                                                "client": "Carla Severina",
                                                "value": 40,
                                                "type": "produto",
                                                "paymentForm": "dinheiro"
                                                })
print(response.headers)
print('ok', response.ok)
if response.ok:
    data = response.json()
    print(data, type(data), data.get('items'))
else:
    print(response.text)
