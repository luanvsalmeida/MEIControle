# %% [markdown]
# ## Inflow

# %%
import requests
path = "/api/inflow"
base_url = "http://localhost:8002"
create_endpoint = f"{base_url}{path}"

response = requests.post(create_endpoint, json={"userId": 1, 
                                                "client": "Carla Severina",
                                                "value": 40,
                                                "type": "produto",
                                                "paymentForm": "dinheiro"
                                                })
print(response.headers)
print('ok', response.ok)
if response.ok:
    data = response.json()
    print(data, type(data), data.get('items'))
else:
    print(response.text)
# Out:
# {'date': 'Tue, 13 May 2025 17:02:00 GMT', 'server': 'uvicorn', 'content-length': '143', 'content-type': 'application/json'}
# ok True
# {'userId': 1, 'inflowId': 3, 'value': 40.0, 'type': 'produto', 'date': '2025-05-13T17:02:01.198949Z', 'client': 'Carla Severina', 'paymentForm': 'dinheiro'} <class 'dict'> None

# %%
import requests
path = "/api/inflow/by_user/1"
base_url = "http://localhost:8002"
create_endpoint = f"{base_url}{path}"
response = requests.get(create_endpoint)
print("ok", response.ok)
if response.ok:
    print(response.json())
# Out:
# ok True
# {'results': [{'client': None, 'userId': 1, 'product': 'bolo', 'type': None, 'value': 20.5, 'inflowId': 1, 'date': '2025-05-15T14:02:00.666905Z', 'paymentForm': None}, {'client': None, 'userId': 1, 'product': 'bolo', 'type': None, 'value': 20.5, 'inflowId': 2, 'date': '2025-05-15T14:47:04.312437Z', 'paymentForm': None}, {'client': None, 'userId': 1, 'product': 'bolo', 'type': None, 'value': 50.0, 'inflowId': 3, 'date': '2025-05-15T14:49:26.585946Z', 'paymentForm': None}], 'count': 3}

# %%
path = "/api/inflow/1"
base_url = "http://localhost:8002"
create_endpoint = f"{base_url}{path}"
response = requests.get(create_endpoint)
print("ok", response.ok)
if response.ok:
    print(response.json())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 base_url = "http://localhost:8002"
#       3 create_endpoint = f"{base_url}{path}"
# ----> 4 response = requests.get(create_endpoint)
#       5 print("ok", response.ok)
#       6 if response.ok:
#
# NameError: name 'requests' is not defined

# %% [markdown]
# ## Outflow

# %%
import requests
path = "/api/outflow"
base_url = "http://localhost:8002"
create_endpoint = f"{base_url}{path}"

response = requests.post(create_endpoint, json={"userId": 1, 
                                                "supplier": "Coca Cola Ltda",
                                                "value": 760,
                                                "type": "produto",
                                                "paymentForm": "dinheiro"
                                                })
print(response.headers)
print('ok', response.ok)
if response.ok:
    data = response.json()
    print(data, type(data), data.get('items'))
else:
    print(response.text)
# Out:
# {'date': 'Tue, 13 May 2025 17:08:33 GMT', 'server': 'uvicorn', 'content-length': '147', 'content-type': 'application/json'}
# ok True
# {'value': 760.0, 'userId': 1, 'type': 'produto', 'date': '2025-05-13T17:08:33.570924Z', 'outflowId': 2, 'supplier': 'Coca Cola Ltda', 'paymentForm': 'dinheiro'} <class 'dict'> None

# %%
import requests
path = "/api/outflow/by_user/1"
base_url = "http://localhost:8002"
create_endpoint = f"{base_url}{path}"
response = requests.get(create_endpoint)
print("ok", response.ok)
if response.ok:
    print(response.json())
# Out:
# ok True
# {'results': [{'outflowId': 1, 'value': 20.0, 'date': '2025-05-15T16:16:09.449320Z', 'paymentForm': None, 'product': 'bolo', 'userId': 1, 'supplier': None, 'type': None}, {'outflowId': 2, 'value': 21.0, 'date': '2025-05-15T16:16:34.368263Z', 'paymentForm': None, 'product': 'pão', 'userId': 1, 'supplier': None, 'type': None}], 'count': 2}

# %%
path = "/api/outflow/1"
base_url = "http://localhost:8002"
create_endpoint = f"{base_url}{path}"
response = requests.get(create_endpoint)
print("ok", response.ok)
if response.ok:
    print(response.json())
# Out:
# ok True
# {'userId': 1, 'value': 200.0, 'type': 'produto', 'date': '2025-05-13T17:08:15.100947Z', 'supplier': 'Nestlê Ltda', 'outflowId': 1, 'paymentForm': 'dinheiro'}

# %% [markdown]
# ## Subscription

# %%
import requests
path = "/api/subscription"
base_url = "http://localhost:8002"
create_endpoint = f"{base_url}{path}"

response = requests.post(create_endpoint, json={"userId": 2, 
                                                "plan": "PRO",
                                                "status": "valid",
                                                "endDate": "2025-08-13T19:57:14.160Z",
                                                })
print(response.headers)
print('ok', response.ok)
if response.ok:
    data = response.json()
    print(data, type(data), data.get('items'))
else:
    print(response.text)
# Out:
# {'date': 'Tue, 13 May 2025 20:02:51 GMT', 'server': 'uvicorn', 'content-length': '118', 'content-type': 'application/json'}
# ok True
# {'status': 'valid', 'subscriptionId': 2, 'endDate': '2025-08-13T19:57:14.160000Z', 'startDate': None, 'userId': 2, 'plan': 'PRO'} <class 'dict'> None

# %%
path = "/api/subscription/by_user/1"
base_url = "http://localhost:8002"
create_endpoint = f"{base_url}{path}"
response = requests.get(create_endpoint)
print("ok", response.ok)
if response.ok:
    print(response.json())
# Out:
# ok True
# {'results': [{'status': 'valid', 'subscriptionId': 1, 'endDate': '2025-08-13T19:57:14.160000Z', 'startDate': None, 'userId': 1, 'plan': 'PRO'}], 'count': 1}

# %%
path = "/api/subscription/by_subscription/2"
base_url = "http://localhost:8002"
create_endpoint = f"{base_url}{path}"
response = requests.get(create_endpoint)
print("ok", response.ok)
if response.ok:
    print(response.json())
# Out:
# ok True
# {'status': 'valid', 'subscriptionId': 2, 'endDate': '2025-08-13T19:57:14.160000Z', 'startDate': None, 'userId': 2, 'plan': 'PRO'}
